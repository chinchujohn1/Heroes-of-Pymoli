# %%
#from ast import literal_eval
import pandas as pd

# %%
import json

# %%
import numpy as np

# %%
df = pd.DataFrame

# %%
players = ".\\purchase_data.json"

# %%
players_pd = pd.read_json(players)
players_df = pd.DataFrame(players_pd)
players_df
players_pd.head()
# Out:
#    Age Gender  Item ID                                  Item Name  Price  \
# 0   38   Male      165                Bone Crushing Silver Skewer   3.37
# 1   21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2   34   Male      174                            Primitive Blade   2.46
# 3   21   Male       92                               Final Critic   1.36
# 4   23   Male       63                             Stormfury Mace   1.27
#
#              SN
# 0     Aelalis34
# 1        Eolo46
# 2   Assastnya25
# 3  Pheusrical25
# 4        Aela59

# %%
# total no of players
total_players = players_df['SN'].nunique()
total_players
# Out:
# 573

# %%
#No of Unique Items
unique_items = players_df['Item ID'].nunique()
unique_items
# Out:
# 183

# %%
#Avg Purchase Price
avg_purchase_price = players_df['Price'].mean()
avg_purchase_price
# Out:
# 2.931192307692303

# %%
#Total no of purchases
total_purchases = len (players_df)
total_purchases
# Out:
# 780

# %%
#Total Revenue
total_revenue = players_pd['Price'].sum()
total_revenue
# Out:
# 2286.3299999999963

# %%
total_gender = players_df["Gender"].count()
male = players_df["Gender"].value_counts()['Male']
female = players_df["Gender"].value_counts()['Female']
non_gender_specific = total_gender - male - female
print(f" Total: {total_gender}\n Male: {male}\n Female: {female}\n non_specfic: {non_gender_specific}")
#Percentage of male & Female
male_percent = (male/total_gender) * 100
female_percent = (female/total_gender) * 100
non_gender_specific_percent = (non_gender_specific/total_gender) * 100
print(f" % Male: {male_percent}\n % Female: {female_percent}\n % non_specifc: {non_gender_specific}")
# Out:
#  Total: 780
#  Male: 633
#  Female: 136
#  non_specfic: 11
#  % Male: 81.15384615384616
#  % Female: 17.435897435897434
#  % non_specifc: 11

# %%
  #Purchasing Analysis (Gender)
players_df.groupby('Gender')['Price'].agg({'Purchase Count':'count','Average Purchase Price':'mean','Total Purchase Price':'sum'})
# Out:
# C:\Users\chinc\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                            136                2.815515
# Male                              633                2.950521
# Other / Non-Disclosed              11                3.249091
#
#                        Total Purchase Price
# Gender
# Female                               382.91
# Male                                1867.68
# Other / Non-Disclosed                 35.74

# %%
# Create bins in which to place values based upon TED Talk views
bins = [0,10,15,20,25,30,35,40,100]

# Create labels for these bins
group_name = ["<10","10-14","15-19","20-24","25-29","30-34",
                "35-39","40+"]

# %%
pd.cut(players_df["Age"], bins, labels=group_name)
# Out:
# 0      35-39
# 1      20-24
# 2      30-34
# 3      20-24
# 4      20-24
# 5      15-19
# 6      15-19
# 7      25-29
# 8      20-24
# 9      30-34
# 10     20-24
# 11     15-19
# 12     25-29
# 13     20-24
# 14     35-39
# 15     20-24
# 16     20-24
# 17     20-24
# 18     25-29
# 19     30-34
# 20     20-24
# 21     10-14
# 22     10-14
# 23     15-19
# 24     10-14
# 25     20-24
# 26     25-29
# 27     30-34
# 28     10-14
# 29     15-19
#        ...
# 750    20-24
# 751    25-29
# 752    10-14
# 753    15-19
# 754    30-34
# 755    20-24
# 756    20-24
# 757    30-34
# 758    15-19
# 759    15-19
# 760    25-29
# 761    25-29
# 762    35-39
# 763    25-29
# 764    20-24
# 765    10-14
# 766    20-24
# 767    15-19
# 768    20-24
# 769    20-24
# 770    20-24
# 771    20-24
# 772    10-14
# 773    20-24
# 774    20-24
# 775    20-24
# 776    10-14
# 777    15-19
# 778    15-19
# 779    20-24
# Name: Age, Length: 780, dtype: category
# ...

# %%
players_df["Age Group"] = pd.cut(players_df["Age"], bins, labels=group_name)
players_df
# Out:
#      Age                 Gender  Item ID  \
# 0     38                   Male      165
# 1     21                   Male      119
# 2     34                   Male      174
# 3     21                   Male       92
# 4     23                   Male       63
# 5     20                   Male       10
# 6     20                   Male      153
# 7     29                 Female      169
# 8     25                   Male      118
# 9     31                   Male       99
# 10    24                   Male       57
# 11    20                   Male       47
# 12    30                   Male       81
# 13    23                   Male       77
# 14    40                   Male       44
# 15    21                   Male       96
# 16    22                 Female      123
# 17    22                 Female       59
# 18    28                   Male       91
# 19    31                   Male      177
# 20    24                   Male       78
# 21    15                   Male        3
# ...

# %%
#Age Demographics
players_df.groupby('Age Group')['Price'].agg({'Purchase Count':'count','Average Purchase Price':'mean','Total Purchase Price':'sum'})
# Out:
# C:\Users\chinc\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
#            Purchase Count  Average Purchase Price  Total Purchase Price
# Age Group
# <10                    32                3.019375                 96.62
# 10-14                  78                2.873718                224.15
# 15-19                 184                2.873587                528.74
# 20-24                 305                2.959377                902.61
# 25-29                  76                2.892368                219.82
# 30-34                  58                3.073448                178.26
# 35-39                  44                2.897500                127.49
# 40+                     3                2.880000                  8.64

# %%
#Top Spender
players1 = players_df.groupby('SN')['Price'].agg({'Purchase Count':'count','Average Purchase Price':'mean','Total Purchase Price':'sum'})
pla = players1.sort_values('Total Purchase Price' , ascending=False) 
pla.head()
# Out:
# C:\Users\chinc\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
#              Purchase Count  Average Purchase Price  Total Purchase Price
# SN
# Undirrala66               5                3.412000                 17.06
# Saedue76                  4                3.390000                 13.56
# Mindimnya67               4                3.185000                 12.74
# Haellysu29                3                4.243333                 12.73
# Eoda93                    3                3.860000                 11.58

# %%
popular_item = players_df.groupby('Item ID')['Price'].count()
popular_item
# Out:
# Item ID
# 0      1
# 1      4
# 2      1
# 3      1
# 4      1
# 5      3
# 6      3
# 7      6
# 8      6
# 9      2
# 10     6
# 11     7
# 12     5
# 13     9
# 14     5
# 15     6
# 16     4
# 17     3
# 18     7
# 19     2
# 20     4
# 21     3
# 22     6
# 23     4
# 24     2
# 25     4
# 26     4
# 27     4
# 28     1
# 29     3
#       ..
# 154    7
# 155    3
# 156    1
# 157    4
# 158    7
# 159    5
# 160    5
# 161    5
# 162    3
# 163    3
# 164    1
# 165    3
# 166    3
# 167    2
# 168    1
# 169    4
# 170    5
# 171    5
# 172    7
# 173    5
# 174    5
# 175    9
# 176    4
# 177    4
# 178    2
# 179    7
# 180    5
# 181    3
# 182    5
# 183    5
# Name: Price, Length: 183, dtype: int64

# %%
most_popular = players_df.groupby('Item ID')['Price'].agg({'Purchase Count':'count','Total Purchase Price':'sum'})
pla =most_popular.sort_values('Purchase Count' , ascending=False) 
pla.head()
# Out:
# C:\Users\chinc\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
#          Purchase Count  Total Purchase Price
# Item ID
# 39                   11                 25.85
# 84                   11                 24.53
# 31                    9                 18.63
# 175                   9                 11.16
# 13                    9                 13.41

# %%
most_profitable = players_df.groupby('Item ID')['Price'].agg({'Purchase Count':'count','Total Purchase Price':'sum'})
pla =most_profitable.sort_values('Total Purchase Price' , ascending=False) 
pla.head()
# Out:
# C:\Users\chinc\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
#          Purchase Count  Total Purchase Price
# Item ID
# 34                    9                 37.26
# 115                   7                 29.75
# 32                    6                 29.70
# 103                   6                 29.22
# 107                   8                 28.88
